# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd

# %%
link = 'https://www.amazon.in/OnePlus-Mirror-Black-128GB-Storage/product-reviews/B07DJHV6VZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'
page = requests.get(link)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">\n <!-- sp:feature:head-start -->\n <head>\n  <script>\n   var aPageStart = (new Date()).getTime();\n  </script>\n  <meta charset="utf-8"/>\n  <!-- sp:feature:cs-optimization -->\n  <meta content="on" http-equiv="x-dns-prefetch-control"/>\n  <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>\n  <link href="https://m.media-amazon.com" rel="dns-prefetch"/>\n  <link href="https://completion.amazon.com" rel="dns-prefetch"/>\n  <!-- sp:feature:aui-assets -->\n  <link href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41SIz69qHYL.css,21qPwhPKAAL.css,01Vctty9pOL.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,01ZfXnjPmmL.css,01oDR3IULNL.css,41-PwE7+H0L.css,01XPHJk60-L.css,01R0k0yxPXL.css,21xVR0NtxzL.css,11gneA3MtJL.css,21fecG8pUzL.css,01RddH8vm-L.css,01CFUgsA-
# ...

# %%
names = soup.find_all('span',class_='a-profile-name')
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())
cust_name
# Out:
# ['Tanmay Shukla',
#  'Surbhi Garg',
#  'Tanmay Shukla',
#  'Surbhi Garg',
#  'klknow',
#  'abdulkadir garari',
#  'Anshu K.',
#  'nagaraj s.',
#  'Regidi Mahesh Dora',
#  'Aakash Sinha',
#  'Mumtaz Alam',
#  'Vaibhav Narvaria']

# %%
cust_name.pop(0)
cust_name
# Out:
# ['Surbhi Garg',
#  'Tanmay Shukla',
#  'Surbhi Garg',
#  'klknow',
#  'abdulkadir garari',
#  'Anshu K.',
#  'nagaraj s.',
#  'Regidi Mahesh Dora',
#  'Aakash Sinha',
#  'Mumtaz Alam',
#  'Vaibhav Narvaria']

# %%
cust_name.pop(0)
cust_name
# Out:
# ['Tanmay Shukla',
#  'Surbhi Garg',
#  'klknow',
#  'abdulkadir garari',
#  'Anshu K.',
#  'nagaraj s.',
#  'Regidi Mahesh Dora',
#  'Aakash Sinha',
#  'Mumtaz Alam',
#  'Vaibhav Narvaria']

# %%
title = soup.find_all('a',class_='review-title-content')
review_title = []
for i in range(0,len(title)):
    review_title.append(title[i].get_text().strip())
review_title
# Out:
# ['Flagship Killer',
#  'Camera quality is very poor.',
#  'Dead on arrival',
#  'Not worth to buy 6T',
#  'Beautiful phone',
#  'Awesome value for the money',
#  'NO WAY GOING TO BE A CUSTOMER OF A COMPANY (Oneplus6T) THAT CANNOT GET NEW CUSTOMER SERVICE CORRECT',
#  'OnePlust 6T McLaren Edition - Salute to Speed!',
#  'Waste of money',
#  'Superb phone']

# %%
rating = soup.find_all('i',class_='review-rating')
rate = []
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())
rate
# Out:
# ['5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '2.0 out of 5 stars'

# %%
review = soup.find_all("span",{"data-hook":"review-body"})
review_content = []
for i in range(0,len(review)):
    review_content.append(review[i].get_text().strip())
review_content
# Out:
# ["I got this phone on Friday evening.Pros:Great battery lifeAmazing performancePremium designImpressive rear and front cameraIn display fingerprint scanner is really fastCons:No headphone jack but you'll get a converterNo notification LEDNo microSD card slotI will give points on my personal experience of 2 days full usage as below:Weight: 9/10OS: 10/10Screen size: 10/10CPU: 10/10Performance: 10/10Storage: 10/10 (you'll get approx 113 gb for use)Battery: 8/10Rear camera: 10/10Front camera: 10/10In display fingerprint scanner: 9/10Face unlock: 10/10I hope this will help full.",
#  'Camera quality is not upto the mark. I visited one plus store and the store representative checked my phone and compared the camera quality with his demo phone. He noticed a significant difference between the two.I request Amazon to replace my phone with a new one as it is evident that this phone has some problems.',
# ...

# %%
df = pd.DataFrame()
df['Customer Name']=cust_name
df['Review title']=review_title
df['Ratings']=rate
df['Reviews']=review_content
df
# Out:
#         Customer Name                                       Review title  \
# 0       Tanmay Shukla                                    Flagship Killer
# 1         Surbhi Garg                       Camera quality is very poor.
# 2              klknow                                    Dead on arrival
# 3   abdulkadir garari                                Not worth to buy 6T
# 4            Anshu K.                                    Beautiful phone
# 5          nagaraj s.                        Awesome value for the money
# 6  Regidi Mahesh Dora  NO WAY GOING TO BE A CUSTOMER OF A COMPANY (On...
# 7        Aakash Sinha     OnePlust 6T McLaren Edition - Salute to Speed!
# 8         Mumtaz Alam                                     Waste of money
# 9    Vaibhav Narvaria                                       Superb phone
#
#               Ratings                                            Reviews
# 0  5.0 out of 5 stars  I got this phone on Friday evening.Pros:Great ...
# ...

# %%
df.to_csv(r'C:\Users\dell\Desktop\ItVedant\webscap.csv',index=False,encoding='utf-8')
df=pd.read_csv(r'C:\Users\dell\Desktop\ItVedant\webscap.csv')
df
# Out:
#         Customer Name                                       Review title  \
# 0       Tanmay Shukla                                    Flagship Killer
# 1         Surbhi Garg                       Camera quality is very poor.
# 2              klknow                                    Dead on arrival
# 3   abdulkadir garari                                Not worth to buy 6T
# 4            Anshu K.                                    Beautiful phone
# 5          nagaraj s.                        Awesome value for the money
# 6  Regidi Mahesh Dora  NO WAY GOING TO BE A CUSTOMER OF A COMPANY (On...
# 7        Aakash Sinha     OnePlust 6T McLaren Edition - Salute to Speed!
# 8         Mumtaz Alam                                     Waste of money
# 9    Vaibhav Narvaria                                       Superb phone
#
#               Ratings                                            Reviews
# 0  5.0 out of 5 stars  I got this phone on Friday evening.Pros:Great ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer Name  10 non-null     object
#  1   Review title   10 non-null     object
#  2   Ratings        10 non-null     object
#  3   Reviews        10 non-null     object
# dtypes: object(4)
# memory usage: 448.0+ bytes

# %%
df.shape
# Out:
# (10, 4)
